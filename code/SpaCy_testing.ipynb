# %% [markdown]
# # A Notebook for exploring SpaCy in attempting to model The Bechdel Test
#
# Following this [article from DataQuest](https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/) has been the source of inspiration for bringing in SpaCy and TfidfVectorizer for this. TfidfVectorizer, as it weighs the occurrence of words within a document in its calculations (think character names in screenplays), will be incredibly useful in our project.

# %%
# Let's bring our mates
import textblob
import string
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
import spacy
import re
import itertools
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# %%
punctuations = string.punctuation

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ### Looking at Named Entity Recognition (NER) Below:
#
# We are going to bring in a gender-guesser function so that we can create a feature that counts the number of women in the film. This would allow for us to see just how many women are in the script (the more women, the higher the chance for passing The Bechdel Test!)

# %%
with open('../data/Scripts/2012.TXT', 'r') as movie:
    movie = movie.read()

# %%
movie_doc = nlp(movie)

# %%
[(ent.text, ent.label_) for ent in movie_doc.ents if ent.label_ == 'PERSON']
# Out:
# [('Harald Kloser\n\n                                                           ',
#   'PERSON'),
#  ('Mozart', 'PERSON'),
#  ('Mozart', 'PERSON'),
#  ('FREDERIC WEST', 'PERSON'),
#  ('West', 'PERSON'),
#  ('SATNAM TSURUTANI', 'PERSON'),
#  ('SATNAM\n\n                    8200 feet', 'PERSON'),
#  ('West', 'PERSON'),
#  ('Satnam', 'PERSON'),
#  ('WEST\n\n                    Helmsley', 'PERSON'),
#  ('SATNAM\n\n                    ', 'PERSON'),
#  ('SATNAM', 'PERSON'),
#  ('SATNAM\n\n                    ', 'PERSON'),
#  ('Satnam', 'PERSON'),
#  ('SATNAM', 'PERSON'),
#  ('ADRIAN HELMSLEY', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('West', 'PERSON'),
#  ('Satnam', 'PERSON'),
#  ('WEST\n\n                    ', 'PERSON'),
#  ('Satnam', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('West', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('THOMAS F. WILSON', 'PERSON'),
#  ('WILSON', 'PERSON'),
#  ('WILSON', 'PERSON'),
#  ('SERGEY MAKARENKO', 'PERSON'),
#  ('Makarenko', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('WILSON', 'PERSON'),
#  ('WILSON', 'PERSON'),
#  ('CHO MING VALLEY', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('LIN PANG', 'PERSON'),
#  ('LIN\n\n                    ', 'PERSON'),
#  ('Lin', 'PERSON'),
#  ('Lin', 'PERSON'),
#  ('Isaacs', 'PERSON'),
#  ('MANFRED PICARD', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('MANFRED PICARD', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('Manfred', 'PERSON'),
#  ('Picard', 'PERSON'),
#  ('Mona Lisa', 'PERSON'),
#  ('MANFRED PICARD\n\n                    ', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('Mona Lisa', 'PERSON'),
#  ('Tikal', 'PERSON'),
#  ('NEWSCASTER', 'PERSON'),
#  ('Tikal', 'PERSON'),
#  ('NEWSCASTER', 'PERSON'),
#  ('JACKSON CURTIS', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('KATE CURTIS', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('GORDON SILBERMAN', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('KATE\n\n                    Noah', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('KATE\n\n                    Jackson', 'PERSON'),
#  ('TONY DELGADO', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('TONY', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('HARRY\n\n                    ', 'PERSON'),
#  ('Audrey', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('MANFRED PICARD', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('MANFRED PICARD\n\n                    ', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('MANFRED PICARD\n\n                    ', 'PERSON'),
#  ('Laura\n\n                    ', 'PERSON'),
#  ('Picard', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('Sally', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('Sally', 'PERSON'),
#  ('Sally', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Picard', 'PERSON'),
#  ('Princess Diana', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Laura\n\n          ', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('WILSON\n\n                    Honey', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ("Lil'bee", 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('NOAH', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Adrian Helmsley', 'PERSON'),
#  ('West', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Curtis', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Curtis', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ("Lil'bee", 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah\n\n          ', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('NOAH\n\n                            ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Mr Anheuser', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie Frost', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Bill\n\n                    ', 'PERSON'),
#  ('Bill', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Bill', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Bill', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie Frost', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('CHARLIE FROST\n\n                            ', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('Hapgood', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Albert Einstein', 'PERSON'),
#  ('Einstein', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Phsssh', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('Sheik', 'PERSON'),
#  ('Bill Gates', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('CHARLIE FROST\n\n                            ', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('KATE\n\n                    ', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('JACKSON\n\n                    ', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Birnbaum', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('WILSON', 'PERSON'),
#  ('Adrian Helmsley', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Helmsley', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('Antonioni', 'PERSON'),
#  ('Zultan\n\n                    Balashin', 'PERSON'),
#  ('YURI KARPOV', 'PERSON'),
#  ('YURI\n\n                    Zultan', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('Karpov', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('TAMARA\n\n                    Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Gonzales\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah\n\n          ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Curtis', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Karpov', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('Alec', 'PERSON'),
#  ('Oleg', 'PERSON'),
#  ('Louis Vuitton', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('ALEC', 'PERSON'),
#  ('ALEC\n\n                    Curtis', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('ALEC\n\n                    Curtis', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('ALEC\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Curtis', 'PERSON'),
#  ('Oleg', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon\n\n          ', 'PERSON'),
#  ('Caltech', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Karate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('JACKSON\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('KATE\n\n                    Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Limo', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('NOAH\n\n                            ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('HARRY', 'PERSON'),
#  ('Tony\n\n                    Delgado', 'PERSON'),
#  ('Harry Helmsley', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('HARRY', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('HARRY', 'PERSON'),
#  ('Tony\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('HARRY\n\n                    ', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('HARRY\n\n                    ', 'PERSON'),
#  ('Jack', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('HARRY\n\n                    ', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('West', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('WEST\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE\n\n                    Lilly', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ("Lil'bee", 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jack Sparrow', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Charlie Frost', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Curtis', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST\n\n                            ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE FROST\n\n                    Easy', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('CHARLIE FROST', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE\n\n                    Jackson', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ("Lil'bee", 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('CHARLIE', 'PERSON'),
#  ('CHARLIE FROST\n\n                    ', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Lil', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Lil', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE\n\n                    Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE\n\n                    Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('GORDON\n\n                    Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('KATE\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Yellowstone\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('SALLY', 'PERSON'),
#  ('Sally', 'PERSON'),
#  ('Sally', 'PERSON'),
#  ('SALLY\n\n                    ', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Helmsley', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('Sally', 'PERSON'),
#  ('SALLY\n\n                    ', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('WILSON', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('Tommy', 'PERSON'),
#  ('Dorothy', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('WILSON', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('WILSON', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ("KATE\n\n                    Gordon's", 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Helmsley', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('Anheuser', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Silberman', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('YURI\n\n                            ', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('SASHA', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Tamara', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Sasha', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('SASHA\n\n                    GOVNO', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Sasha', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('Lin', 'PERSON'),
#  ('Lin', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('Pang', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('MRS', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('Lin', 'PERSON'),
#  ('Cho Ming', 'PERSON'),
#  ('Pang', 'PERSON'),
#  ('MRS', 'PERSON'),
#  ('Lin', 'PERSON'),
#  ('Pang', 'PERSON'),
#  ('MRS', 'PERSON'),
#  ('Laem Song', 'PERSON'),
#  ('Pang', 'PERSON'),
#  ('OLEG', 'PERSON'),
#  ('Alec', 'PERSON'),
#  ('Oleg', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('ALEC\n\n                    ', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Aston Martin', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('ALEC\n\n                    ', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('NOAH', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Silberman', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('TAMARA\n\n                    ', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('KATE\n\n                    ', 'PERSON'),
#  ("Lil'bee", 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Charlie', 'PERSON'),
#  ('TAMARA\n\n                    ', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE\n\n                    ', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('Karpov', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('Curtis', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('SASHA', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Sasha', 'PERSON'),
#  ('SASHA', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Da Vinci', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('LAURA', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Helmsley', 'PERSON'),
#  ('West', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('Sally', 'PERSON'),
#  ('Dorothy Jones', 'PERSON'),
#  ('Harry\n\n                    Helmsley', 'PERSON'),
#  ('SALLY\n\n                    ', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Makarenko', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Benedict XVI', 'PERSON'),
#  ('Antonioni', 'PERSON'),
#  ('Michelangelo', 'PERSON'),
#  ('Neng Pang', 'PERSON'),
#  ('Neng', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE\n\n                    ', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Cho Ming', 'PERSON'),
#  ('WEST\n\n                    ', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('TONY\n\n                    ', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Tony', 'PERSON'),
#  ('HARRY', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Harry', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('WILSON\n\n                    ', 'PERSON'),
#  ('Dorothy', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('West', 'PERSON'),
#  ('Cho Ming', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('Adrian', 'PERSON'),
#  ('ADRIAN\n\n                    ', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('NOAH', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('KATE\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ("Lil'bee", 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Tamara', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Kate', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('GORDON', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('SASHA', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Hapgood', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('SASHA', 'PERSON'),
#  ('SASHA', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI\n\n                            ', 'PERSON'),
#  ('TAMARA\n\n                    Yuri', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('SASHA\n\n                    CHTO ZA', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('SASHA', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('SASHA\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('SASHA', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Bentley', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Curtis', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('Noah', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('NOAH\n\n                    ', 'PERSON'),
#  ('Gordon', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Tamara', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('KATE', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('JACKSON', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Jackson', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('TAMARA\n\n                    ', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('TAMARA', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI', 'PERSON'),
#  ('Jackson\n\n                    ', 'PERSON'),
#  ('GORDON\n\n                    ', 'PERSON'),
#  ('Anheuser', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('MICHAELS\n\n                    ', 'PERSON'),
#  ('Richard Michaels', 'PERSON'),
#  ('Michaels', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('MICHAELS\n\n                    ', 'PERSON'),
#  ('Wilson', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('MICHAELS', 'PERSON'),
#  ('MICHAELS\n\n                    ', 'PERSON'),
#  ('Michaels', 'PERSON'),
#  ('MICHAELS', 'PERSON'),
#  ('CHO MING VALLEY', 'PERSON'),
#  ('Laura', 'PERSON'),
#  ('Yuri', 'PERSON'),
#  ('YURI\n\n                    ', 'PERSON'),
#  ...]

# %%
bechdel_df = pd.read_csv('../data/bechdel_df.csv')

# %%
bechdel_df.head()
# Out:
#    Unnamed: 0  rating                  title  year     imdbid  \
# 0           0       1                warrior  2011  1291584.0
# 1           1       1             collateral  2004   369339.0
# 2           8       1                  gamer  2009  1034032.0
# 3           9       1                 wanted  2008   493464.0
# 4          10       0  2001: a space odyssey  1968    62622.0
#
#                                               script  simple_bechdel
# 0                                  WARRIOR       ...               0
# 1                                           COLLA...               0
# 2                                GAMER           ...               0
# 3                                    WANTED      ...               0
# 4      2001: A SPACE ODYSSEY    Screenplay   by  ...               0

# %%
bechdel_df.drop(columns=['Unnamed: 0', 'rating', 'year', 'imdbid'], axis=1, inplace=True)

# %%
bechdel_df.head()
# Out:
#                    title                                             script  \
# 0                warrior                                  WARRIOR       ...
# 1             collateral                                           COLLA...
# 2                  gamer                                GAMER           ...
# 3                 wanted                                    WANTED      ...
# 4  2001: a space odyssey      2001: A SPACE ODYSSEY    Screenplay   by  ...
#
#    simple_bechdel
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
bechdel_df['simple_bechdel'].value_counts(normalize=True)
# Out:
# 1    0.51634
# 0    0.48366
# Name: simple_bechdel, dtype: float64

# %%
bechdel_df.shape
# Out:
# (459, 3)

# %% [markdown]
# ### Feature Creation: Creating a count of female characters in a screenplay
#
# The below function will create a feature that stores the number of female characters in the film for us to use as a feature in calculating Bechdel probability

# %%
def read_name_file(filename):
    names = []
    with open(filename, "r") as f:
        for line in f:
            if not line.startswith("#") and line.strip() != "":  # remove comments and empty lines
                names.append(line.strip().lower())
    return names

# %%
female_names = "../data/female.txt"
male_names = "../data/male.txt"
male_names = read_name_file(male_names)
female_names = read_name_file(female_names)

# %%
def character_list(file):
    #names = []
    #with open(file, 'r') as f:
        #for line in file:
            #re.findall(r'b[A-Z]', f)
    names = ' '.join(re.findall(r'[A-Z]+', file)).lower().split()
    #now let's search through the list and find only human names
    female_characters = []
    male_characters = []
    for i in names:
        if i in female_names:
            female_characters.append(i)
        elif i in male_names:
            male_characters.append(i)
        else:
            pass
    return len(set(female_characters))

# %%
character_list(bechdel_df['script'][5])
# Out:
# ['cruel', 'intentions', 'r', 'k', 'l', 'l', 'd', 'c', 'd', 'l', 'f', 'ext', 'manhattan', 'skyline', 'day', 'w', 'm', 'f', 'a', 'a', 'move', 'zoom', 'int', 'therapist', 's', 'office', 'day', 'a', 'dr', 'greenbaum', 'b', 'j', 'f', 'a', 'sebastian', 'valmont', 't', 'dr', 'greenbaum', 'j', 'w', 'sebastian', 'i', 'dr', 'greenbaum', 'a', 'sebastian', 'i', 's', 'dr', 'greenbaum', 't', 's', 'd', 'g', 'sebastian', 'w', 't', 'i', 'i', 'i', 't', 'i', 'd', 'g', 'sebastian', 'l', 'i', 'i', 't', 't', 'y', 'y', 'y', 'y', 'i', 'dr', 'greenbaum', 'b', 'sebastian', 'i', 'dr', 'greenbaum', 'd', 'sebastian', 'l', 'c', 't', 't', 't', 'dr', 'greenbaum', 'i', 'sebastian', 's', 'dr', 'greenbaum', 'n', 't', 'sebastian', 'w', 'i', 'y', 'y', 'k', 'dr', 'greenbaum', 't', 'y', 'i', 'sebastian', 'd', 'd', 'y', 's', 'f', 'sebastian', 'h', 'dr', 'greenbaum', 'y', 'i', 's', 'sebastian', 'i', 'dr', 'greenbaum', 'n', 'i', 'sebastian', 'y', 'dr', 'greenbaum', 'i', 'i', 'sebastian', 'w', 's', 'dr', 'greenbaum', 'm', 'r', 'sebastian', 'y', 'dr', 'greenbaum', 'd', 'r', 'p', 's', 'sebastian', 'r', 'c', 'dr', 'greenbaum', 'g', 's', 'sebastian', 'w', 'i', 'dr', 'greenbaum', 'w', 's', 'dr', 'greenbaum', 'a', 't', 'b', 'h', 's', 'dr', 'greenbaum', 'r', 'intercut', 'with', 'int', 'rachel', 's', 'bedroom', 'day', 'rachel', 'd', 'g', 'rachel', 'h', 'dr', 'greenbaum', 'h', 'r', 'rachel', 'h', 'i', 'dr', 'greenbaum', 'w', 'rachel', 'y', 'i', 's', 'dr', 'greenbaum', 'a', 'rachel', 'w', 't', 'we', 'pan', 'over', 'to', 'her', 'computer', 'console', 'close', 'on', 'computer', 'monitor', 'a', 't', 'i', 'l', 'b', 'b', 'r', 'p', 'dr', 'greenbaum', 'w', 'rachel', 'n', 'dr', 'greenbaum', 'j', 'c', 'rachel', 'i', 'h', 'a', 'i', 't', 'm', 'a', 'm', 'm', 'int', 'therapist', 's', 'office', 'building', 'hallway', 'day', 'd', 'g', 's', 'dr', 'greenbaum', 'y', 'd', 'g', 's', 'dr', 'greenbaum', 'y', 'y', 'a', 'dentist', 'h', 'd', 'g', 'dr', 'greenbaum', 'f', 'h', 'h', 'ext', 'valmont', 'townhouse', 'day', 'a', 'meter', 'maid', 'p', 's', 'meter', 'maid', 'y', 's', 'h', 'int', 'valmont', 'townhouse', 'kitchen', 'day', 'a', 'series', 'of', 'shots', 'close', 'on', 'a', 'whack', 'a', 'close', 'on', 't', 'close', 'on', 't', 'int', 'valmont', 'townhouse', 'hallway', 'day', 'close', 'on', 't', 'int', 'valmont', 'townhouse', 'living', 'room', 'day', 'a', 'm', 'e', 'v', 'sook', 'hee', 'v', 'kathryn', 'merteuil', 'wasp', 'e', 'c', 's', 'bunny', 'caldwell', 'cecile', 'caldwell', 's', 't', 'k', 'b', 'mrs', 'caldwell', 'i', 'c', 'o', 'y', 'b', 'i', 'w', 'kathryn', 'i', 's', 'h', 'k', 'kathryn', 's', 'h', 'v', 't', 's', 'h', 't', 's', 'h', 'cecile', 'w', 'kathryn', 'i', 'v', 'mrs', 'caldwell', 'k', 'a', 'o', 'p', 'f', 'c', 'l', 'kathryn', 'f', 'y', 'mrs', 'caldwell', 'h', 'i', 'w', 'kathryn', 'i', 'i', 'i', 'g', 'c', 'mrs', 'caldwell', 't', 'cecile', 'w', 'mrs', 'caldwell', 'c', 'k', 'y', 'k', 's', 'kathryn', 'd', 'm', 'o', 'mrs', 'caldwell', 'l', 's', 'i', 'sebastian', 'o', 's', 'i', 'm', 'c', 's', 'h', 'sebastian', 'n', 'm', 'c', 'mrs', 'caldwell', 'y', 'c', 'sebastian', 'm', 'cecile', 'm', 'a', 'sebastian', 'h', 'b', 'i', 'kathryn', 'c', 'o', 'sebastian', 'o', 'cecile', 'w', 'sebastian', 'i', 'cecile', 'b', 'i', 'sebastian', 'i', 'h', 'c', 'mrs', 'caldwell', 'i', 'k', 't', 'k', 'c', 'kathryn', 'i', 'cecile', 't', 's', 'n', 'sebastian', 'c', 'mrs', 'caldwell', 'l', 'c', 'n', 'c', 'm', 'c', 'k', 'sebastian', 'd', 'm', 'w', 'kathryn', 'i', 'k', 's', 's', 't', 'kathryn', 't', 'sebastian', 'l', 'h', 'b', 'z', 'kathryn', 'h', 'k', 'kathryn', 'w', 't', 'sebastian', 'i', 'h', 'sebastian', 'i', 'm', 'd', 'h', 'b', 'sebastian', 'n', 'h', 'sebastian', 'i', 'i', 'h', 'kathryn', 'o', 'w', 'i', 'sebastian', 'w', 'ext', 'park', 'day', 'court', 'reynolds', 'a', 'p', 'a', 'f', 'kathryn', 'v', 'o', 'y', 'c', 'r', 'g', 'r', 'k', 's', 'h', 'sebastian', 'v', 'o', 'y', 'n', 'f', 'o', 'j', 'w', 'int', 'valmont', 'townhouse', 'living', 'room', 'day', 'k', 's', 'kathryn', 'h', 'w', 's', 'kathryn', 'a', 'h', 'ext', 'public', 'pa ...
# 9

# %%
def women_count(df):
    for movie in df:
        bechdel_df['women'] = character_list(movie)
    return bechdel_df

# %%
bechdel_df.head()
# Out:
#                    title                                             script  \
# 0                warrior                                  WARRIOR       ...
# 1             collateral                                           COLLA...
# 2                  gamer                                GAMER           ...
# 3                 wanted                                    WANTED      ...
# 4  2001: a space odyssey      2001: A SPACE ODYSSEY    Screenplay   by  ...
#
#    simple_bechdel
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
bechdel_df['women'] = bechdel_df['script'].apply(character_list)

# %%
bechdel_df['women'].value_counts()
# Out:
# 14    31
# 12    31
# 15    30
# 9     29
# 13    27
# 11    25
# 10    24
# 7     21
# 8     21
# 6     20
# 16    17
# 5     17
# 17    15
# 20    15
# 19    14
# 21    13
# 23    13
# 22    13
# 4     12
# 18    12
# 3      7
# 24     7
# 26     6
# 27     6
# 28     6
# 2      5
# 1      4
# 32     3
# 33     3
# 34     3
# 30     2
# 35     1
# 39     1
# 38     1
# 0      1
# 29     1
# 25     1
# 44     1
# Name: women, dtype: int64

# %%
# Load English tokenizer, tagger, parser, NER and word vectors
parser = English()

# %%
# Creating our tokenizer function
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    mytokens = parser(sentence)

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [word.lower() for word in mytokens]

    #mytokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens]
    
    # Removing stop words
    mytokens = [word for word in mytokens if word not in stop_words and word not in punctuations]

    # return preprocessed list of tokens
    return mytokens

# %%
spacy_tokenizer('John has a beard and he likes to keep it neat')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-221-4448bb12c619> in <module>
# ----> 1 spacy_tokenizer('John has a beard and he likes to keep it neat')
#
# <ipython-input-220-a2109e679285> in spacy_tokenizer(sentence)
#       5
#       6     # Lemmatizing each token and converting each token into lowercase
# ----> 7     mytokens = [word.lower() for word in mytokens]
#       8
#       9     #mytokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens]
#
# <ipython-input-220-a2109e679285> in <listcomp>(.0)
#       5
#       6     # Lemmatizing each token and converting each token into lowercase
# ----> 7     mytokens = [word.lower() for word in mytokens]
#       8
#       9     #mytokens = [word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens]
#
# TypeError: 'int' object is not callable

# %%
# got this code from Amir Semsarzadeh
def poles(text):
    try:
        return TextBlob(text).polarity
    except:
        return None
def subj(text):
    try:
        return TextBlob(text).subjectivity
    except:
        return None
#calls in each seperately for direct use alternatively you could get 
#it in a tuple but getting both values in the column is going to be annoying. 
bechdel_df['script_polarity'] = bechdel_df['script'].apply(poles)
bechdel_df['script_subjectivity'] = bechdel_df['script'].apply(subj)

# %%
bechdel_df.head()
# Out:
#                    title                                             script  \
# 0                warrior                                  WARRIOR       ...
# 1             collateral                                           COLLA...
# 2                  gamer                                GAMER           ...
# 3                 wanted                                    WANTED      ...
# 4  2001: a space odyssey      2001: A SPACE ODYSSEY    Screenplay   by  ...
#
#    simple_bechdel  women script_polarity script_subjectivity
# 0               0     15            None                None
# 1               0     12            None                None
# 2               0     28            None                None
# 3               0      8            None                None
# 4               0      7            None                None

# %%
print(punctuations)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
# Custom transformer using spaCy
class predictors(TransformerMixin):
    def transform(self, X, **transform_params):
        # Cleaning Text
        return [clean_text(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

    def get_params(self, deep=True):
        return {}

# Basic function to clean the text
def clean_text(text):
    # Removing spaces and converting text into lowercase
    return text.strip().lower()

# %%
# Let's instantiate TF-IDF here
tfidf_vector = TfidfVectorizer(tokenizer = spacy_tokenizer)

# %%
X = bechdel_df[['script', 'women']]
y = bechdel_df['simple_bechdel']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
logreg = LogisticRegression()

# %%
# Create pipeline using Bag of Words
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', tfidf_vector),
                 ('classifier', logreg)])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('cleaner', <__main__.predictors object at 0x7fd554890880>),
#                 ('vectorizer',
#                  TfidfVectorizer(tokenizer=<function spacy_tokenizer at 0x7fd5dd300280>)),
#                 ('classifier', LogisticRegression())])

# %%
preds = pipe.predict(X_test)

# %%
print("Logistic Regression Accuracy:", accuracy_score(y_test, preds))
print("Logistic Regression Precision:", precision_score(y_test, preds))
print("Logistic Regression Recall:", recall_score(y_test, preds))
# Out:
# Logistic Regression Accuracy: 0.4782608695652174
# Logistic Regression Precision: 0.5483870967741935
# Logistic Regression Recall: 0.5151515151515151
