# %%
import numpy as np
import pandas as pd
import re

# %%
def read_name_file(filename):
    """Read a file containing a list of names
        Args:
            filename: a file containing a name for each row
        Returns:
            An array of names from the input file
    """
    names = []
    with open(filename, "r") as f:
        for line in f:
            if not line.startswith("#") and line.strip() != "":  # remove comments and empty lines
                names.append(line.strip().lower())
    return pd.DataFrame(names)

# %%
def character_list(file):
    names = []
    with open(file, 'r') as f:
        for line in f:
            #re.findall(r'b[A-Z]', f)
            names.append(re.findall(r'[A-Z]', line))
    return names

# %%
character_list('../data/Scripts/2012.txt')
# Out:
# [[],
#  [],
#  ['W'],
#  [],
#  ['R', 'E', 'H', 'K'],
#  [],
#  ['S', 'D'],
#  [],
#  ['F'],
#  [],
#  ['O', 'V', 'E', 'R', 'B', 'L', 'A', 'C', 'K'],
#  [],
#  ['W', 'M', 'A'],
#  [],
#  ['C', 'C', 'A'],
#  [],
#  ['F', 'A', 'D', 'E', 'U', 'P'],
#  [],
#  ['E',
#   'X',
#   'T',
#   'T',
#   'H',
#   'E',
#   'S',
#   'O',
#   'L',
#   'A',
#   'R',
#   'S',
#   'Y',
#   'S',
#   'T',
#   'E',
#   'M'],
#  [],
#  ['S'],
#  [],
#  ['B', 'S', 'S'],
#  [],
#  [],
#  [],
#  ['T'],
#  [],
#  ['J'],
#  [],
#  ['T'],
#  [],
#  [],
#  [],
#  ['F', 'A', 'D', 'E', 'T', 'O', 'B', 'L', 'A', 'C', 'K'],
#  [],
#  [],
#  [],
#  ['F', 'A', 'D', 'E', 'U', 'P'],
#  [],
#  ['E',
#   'X',
#   'T',
#   'C',
#   'O',
#   'U',
#   'N',
#   'T',
#   'R',
#   'Y',
#   'S',
#   'I',
#   'D',
#   'E',
#   'I',
#   'N',
#   'D',
#   'I',
#   'A',
#   'S',
#   'U',
#   'N',
#   'S',
#   'E',
#   'T'],
#  [],
#  ['M'],
#  [],
#  ['P',
#   'R',
#   'O',
#   'F',
#   'F',
#   'R',
#   'E',
#   'D',
#   'E',
#   'R',
#   'I',
#   'C',
#   'W',
#   'E',
#   'S',
#   'T'],
#  [],
#  [],
#  [],
#  ['A', 'I', 'B', 'O', 'Y'],
#  [],
#  [],
#  [],
#  ['T', 'P'],
#  [],
#  ['P', 'R', 'O', 'F', 'W', 'E', 'S', 'T'],
#  [],
#  ['W'],
#  [],
#  ['B', 'T'],
#  [],
#  [],
#  [],
#  ['I', 'T'],
#  [],
#  ['P'],
#  [],
#  ['T', 'I', 'A'],
#  [],
#  ['U', 'N', 'D'],
#  [],
#  [],
#  [],
#  ['I',
#   'N',
#   'T',
#   'N',
#   'A',
#   'G',
#   'A',
#   'D',
#   'E',
#   'N',
#   'G',
#   'M',
#   'I',
#   'N',
#   'E',
#   'I',
#   'N',
#   'D',
#   'I',
#   'A',
#   'S',
#   'U',
#   'N',
#   'S',
#   'E',
#   'T'],
#  [],
#  ['A', 'A'],
#  [],
#  ['W', 'P', 'W'],
#  [],
#  ['D',
#   'R',
#   'S',
#   'A',
#   'T',
#   'N',
#   'A',
#   'M',
#   'T',
#   'S',
#   'U',
#   'R',
#   'U',
#   'T',
#   'A',
#   'N',
#   'I'],
#  [],
#  ['P', 'R', 'O', 'F', 'W', 'E', 'S', 'T'],
#  [],
#  ['H'],
#  [],
#  ['S', 'A', 'T', 'N', 'A', 'M'],
#  [],
#  ['U'],
#  [],
#  ['P'],
#  [],
#  ['A', 'P', 'W', 'S'],
#  [],
#  [],
#  [],
#  ['P', 'R', 'O', 'F', 'W', 'E', 'S', 'T'],
#  [],
#  ['H'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['S', 'A', 'T', 'N', 'A', 'M'],
#  [],
#  ['C', 'B'],
#  [],
#  [],
#  [],
#  ['T', 'A'],
#  [],
#  ['W', 'H', 'I', 'T', 'E', 'C', 'O', 'A', 'T', 'S'],
#  [],
#  [],
#  [],
#  ['S', 'A', 'T', 'N', 'A', 'M', 'C', 'O', 'N', 'T', 'D'],
#  [],
#  ['T'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['P', 'R', 'O', 'F', 'W', 'E', 'S', 'T'],
#  [],
#  ['H'],
#  [],
#  ['S', 'A', 'T', 'N', 'A', 'M'],
#  [],
#  ['W', 'P'],
#  [],
#  ['S', 'T'],
#  [],
#  [],
#  [],
#  ['S', 'A', 'T', 'N', 'A', 'M', 'C', 'O', 'N', 'T', 'D'],
#  [],
#  ['T'],
#  [],
#  [],
#  [],
#  ['P', 'W', 'W'],
#  [],
#  [],
#  [],
#  ['C', 'U', 'T', 'T', 'O'],
#  [],
#  [],
#  [],
#  ['E',
#   'X',
#   'T',
#   'L',
#   'A',
#   'R',
#   'G',
#   'E',
#   'T',
#   'E',
#   'R',
#   'R',
#   'A',
#   'C',
#   'E',
#   'W',
#   'A',
#   'S',
#   'H',
#   'I',
#   'N',
#   'G',
#   'T',
#   'O',
#   'N',
#   'D',
#   'C',
#   'E',
#   'V',
#   'E',
#   'N',
#   'I',
#   'N',
#   'G'],
#  [],
#  ['A', 'T'],
#  [],
#  ['A', 'W', 'M'],
#  [],
#  ['C', 'B'],
#  [],
#  ['A',
#   'D',
#   'R',
#   'I',
#   'A',
#   'N',
#   'H',
#   'E',
#   'L',
#   'M',
#   'S',
#   'L',
#   'E',
#   'Y',
#   'P',
#   'O',
#   'L',
#   'I',
#   'T',
#   'I',
#   'C',
#   'A',
#   'L'],
#  [],
#  ['A', 'I', 'D', 'E', 'S', 'H', 'A', 'A'],
#  [],
#  ['O',
#   'C',
#   'A',
#   'R',
#   'L',
#   'A',
#   'N',
#   'H',
#   'E',
#   'U',
#   'S',
#   'E',
#   'R',
#   'W',
#   'H',
#   'C'],
#  [],
#  ['S'],
#  [],
#  ['P', 'O', 'L', 'I', 'T', 'I', 'C', 'A', 'L', 'A', 'I', 'D'],
#  [],
#  ['L', 'A', 'A'],
#  [],
#  ['P', 'D'],
#  [],
#  [],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['I', 'W'],
#  [],
#  ['W'],
#  [],
#  ['H'],
#  [],
#  ['P', 'O', 'L', 'I', 'T', 'I', 'C', 'A', 'L', 'A', 'I', 'D'],
#  [],
#  ['W', 'A', 'S'],
#  [],
#  ['C'],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['S'],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R', 'O', 'S'],
#  [],
#  ['S'],
#  [],
#  ['A', 'A'],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['S', 'H', 'O', 'C', 'K', 'E', 'D'],
#  [],
#  ['Y', 'N'],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R'],
#  [],
#  ['W'],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['W'],
#  [],
#  ['W'],
#  [],
#  [],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R'],
#  [],
#  ['I', 'H', 'I'],
#  [],
#  [],
#  [],
#  ['A'],
#  [],
#  ['P', 'O', 'L', 'I', 'T', 'I', 'C', 'A', 'L', 'A', 'I', 'D'],
#  [],
#  ['T'],
#  [],
#  ['A', 'A'],
#  [],
#  ['C', 'O', 'N', 'T', 'I', 'N', 'U', 'E', 'D'],
#  [],
#  [],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  [],
#  [],
#  ['P', 'W'],
#  [],
#  ['P', 'R', 'O', 'F', 'W', 'E', 'S', 'T', 'O', 'S'],
#  [],
#  ['I'],
#  [],
#  ['I',
#   'N',
#   'T',
#   'L',
#   'I',
#   'V',
#   'I',
#   'N',
#   'G',
#   'R',
#   'O',
#   'O',
#   'M',
#   'S',
#   'A',
#   'T',
#   'N',
#   'A',
#   'M',
#   'S',
#   'H',
#   'O',
#   'U',
#   'S',
#   'E',
#   'N',
#   'I',
#   'G',
#   'H',
#   'T'],
#  [],
#  ['P', 'W', 'I'],
#  [],
#  ['S'],
#  [],
#  ['P', 'R', 'O', 'F', 'W', 'E', 'S', 'T'],
#  [],
#  ['L', 'A', 'T'],
#  [],
#  [],
#  [],
#  ['S', 'I'],
#  [],
#  [],
#  [],
#  ['I',
#   'N',
#   'T',
#   'H',
#   'A',
#   'L',
#   'L',
#   'W',
#   'A',
#   'Y',
#   'W',
#   'H',
#   'I',
#   'T',
#   'E',
#   'H',
#   'O',
#   'U',
#   'S',
#   'E',
#   'D',
#   'A',
#   'Y'],
#  [],
#  ['A', 'A', 'W', 'H'],
#  [],
#  [],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['S', 'P'],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R'],
#  [],
#  ['H'],
#  [],
#  [],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['F'],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R'],
#  [],
#  ['I'],
#  [],
#  ['Y'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['I', 'I'],
#  [],
#  ['I'],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R'],
#  [],
#  ['S'],
#  [],
#  ['E', 'A'],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['C'],
#  [],
#  ['I'],
#  [],
#  ['C', 'O', 'N', 'T', 'I', 'N', 'U', 'E', 'D'],
#  [],
#  [],
#  [],
#  ['F', 'A'],
#  [],
#  [],
#  [],
#  ['S'],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R'],
#  [],
#  ['W'],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['A', 'I', 'I'],
#  [],
#  ['H', 'P', 'W'],
#  [],
#  ['U', 'S'],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R'],
#  [],
#  ['W'],
#  [],
#  ['A', 'D', 'R', 'I', 'A', 'N'],
#  [],
#  ['N'],
#  [],
#  ['A', 'N', 'H', 'E', 'U', 'S', 'E', 'R'],
#  [],
#  ['L', 'H'],
#  [],
#  ['A'],
#  [],
#  ['F', 'A', 'D', 'E', 'T', 'O', 'B', 'L', 'A', 'C', 'K'],
#  [],
#  [],
#  [],
#  ['F', 'A', 'D', 'E', 'U', 'P'],
#  [],
#  ['E',
#   'X',
#   'T',
#   'S',
#   'E',
#   'V',
#   'I',
#   'L',
#   'L',
#   'E',
#   'S',
#   'P',
#   'A',
#   'I',
#   'N',
#   'D',
#   'A',
#   'Y'],
#  [],
#  ['G', 'S', 'R'],
#  [],
#  [],
#  [],
#  ['W', 'P', 'R', 'O', 'T', 'E', 'S', 'T', 'E', 'R', 'S', 'A', 'G'],
#  [],
#  ['A'],
#  [],
#  [],
#  [],
#  ['I',
#   'N',
#   'T',
#   'B',
#   'I',
#   'G',
#   'H',
#   'A',
#   'L',
#   'L',
#   'A',
#   'L',
#   'H',
#   'A',
#   'M',
#   'B',
#   'R',
#   'A',
#   'D',
#   'A',
#   'Y'],
#  [],
#  ['W', 'A'],
#  [],
#  ['G'],
#  [],
#  [],
#  [],
#  ['T',
#   'P',
#   'U',
#   'S',
#   'T',
#   'H',
#   'O',
#   'M',
#   'A',
#   'S',
#   'F',
#   'W',
#   'I',
#   'L',
#   'S',
#   'O',
#   'N'],
#  [],
#  ['H'],
#  [],
#  [],
#  [],
#  ['P',
#   'R',
#   'E',
#   'S',
#   'I',
#   'D',
#   'E',
#   'N',
#   'T',
#   'W',
#   'I',
#   'L',
#   'S',
#   'O',
#   'N',
#   'O',
#   'S'],
#  [],
#  ['G', 'M'],
#  [],
#  ['F', 'P', 'H', 'A'],
#  [],
#  ['A'],
#  [],
#  ['C', 'O', 'N', 'T', 'I', 'N', 'U', 'E', 'D'],
#  [],
#  [],
#  [],
#  ['P',
#   'R',
#   'E',
#   'S',
#   'I',
#   'D',
#   'E',
#   'N',
#   'T',
#   'W',
#   'I',
#   'L',
#   'S',
#   'O',
#   'N',
#   'C',
#   'O',
#   'N',
#   'T',
#   'D'],
#  [],
#  ['I'],
#  [],
#  ['H'],
#  [],
#  ['S'],
#  [],
#  [],
#  [],
#  ['A',
#   'T',
#   'R',
#   'P',
#   'S',
#   'E',
#   'R',
#   'G',
#   'E',
#   'Y',
#   'M',
#   'A',
#   'K',
#   'A',
#   'R',
#   'E',
#   'N',
#   'K',
#   'O'],
#  [],
#  [],
#  [],
#  ['R',
#   'U',
#   'S',
#   'S',
#   'I',
#   'A',
#   'N',
#   'I',
#   'N',
#   'T',
#   'E',
#   'R',
#   'P',
#   'R',
#   'E',
#   'T',
#   'E',
#   'R'],
#  [],
#  ['M', 'M'],
#  [],
#  [],
#  [],
#  ['P', 'W', 'R', 'C'],
#  [],
#  ['P', 'R', 'E', 'S', 'I', 'D', 'E', 'N', 'T', 'W', 'I', 'L', 'S', 'O', 'N'],
#  [],
#  ['M', 'P'],
#  [],
#  ['I'],
#  [],
#  ['E'],
#  [],
#  ['I'],
#  [],
#  [],
#  [],
#  ['A', 'R', 'P'],
#  [],
#  [],
#  [],
#  ['T', 'A'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['T', 'P'],
#  [],
#  ['P',
#   'R',
#   'E',
#   'S',
#   'I',
#   'D',
#   'E',
#   'N',
#   'T',
#   'W',
#   'I',
#   'L',
#   'S',
#   'O',
#   'N',
#   'C',
#   'O',
#   'N',
#   'T',
#   'D'],
#  [],
#  ['S', 'I'],
#  [],
#  [],
#  [],
#  ['I'],
#  [],
#  ['P', 'A', 'U', 'S', 'E'],
#  [],
#  ['H'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['D'],
#  [],
#  ['P',
#   'R',
#   'E',
#   'S',
#   'I',
#   'D',
#   'E',
#   'N',
#   'T',
#   'W',
#   'I',
#   'L',
#   'S',
#   'O',
#   'N',
#   'C',
#   'O',
#   'N',
#   'T',
#   'D'],
#  [],
#  ['T'],
#  [],
#  [],
#  [],
#  ['C', 'U', 'T', 'T', 'O'],
#  [],
#  ['E',
#   'X',
#   'T',
#   'C',
#   'H',
#   'O',
#   'M',
#   'I',
#   'N',
#   'G',
#   'V',
#   'A',
#   'L',
#   'L',
#   'E',
#   'Y',
#   'T',
#   'I',
#   'B',
#   'E',
#   'T',
#   'D',
#   'A',
#   'W',
#   'N'],
#  [],
#  ['A', 'C'],
#  [],
#  ['T', 'W'],
#  [],
#  ['C', 'O', 'N', 'T', 'I', 'N', 'U', 'E', 'D'],
#  [],
#  [],
#  [],
#  ['A', 'C', 'C', 'O', 'L', 'O', 'N', 'E', 'L'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['V', 'O', 'I', 'C', 'E', 'O', 'S'],
#  [],
#  ['C'],
#  [],
#  ['Y'],
#  [],
#  [],
#  [],
#  ['E',
#   'X',
#   'T',
#   'V',
#   'I',
#   'L',
#   'L',
#   'A',
#   'G',
#   'E',
#   'T',
#   'I',
#   'B',
#   'E',
#   'T',
#   'D',
#   'A',
#   'Y'],
#  [],
#  ['S'],
#  [],
#  [],
#  [],
#  ['V', 'O', 'I', 'C', 'E', 'O', 'S'],
#  [],
#  ['S'],
#  [],
#  [],
#  [],
#  ['P', 'R', 'C'],
#  [],
#  [],
#  [],
#  ['N', 'E', 'N', 'G', 'P', 'A', 'N', 'G'],
#  [],
#  ['P', 'A', 'R', 'E', 'N', 'T', 'S'],
#  [],
#  ['E',
#   'X',
#   'T',
#   'S',
#   'C',
#   'H',
#   'O',
#   'O',
#   'L',
#   'T',
#   'I',
#   'B',
#   'E',
#   'T',
#   'D',
#   'A',
#   'Y'],
#  [],
#  ['N', 'L', 'I', 'N', 'P', 'A', 'N', 'G'],
#  [],
#  ['T'],
#  [],
#  ['H'],
#  [],
#  ['L', 'I', 'N'],
#  [],
#  ['I'],
#  [],
#  ['T', 'C'],
#  [],
#  [],
#  [],
#  ['C', 'O', 'L', 'O', 'N', 'E', 'L'],
#  [],
#  ['W'],
#  [],
#  ['E', 'A'],
#  [],
#  ['C', 'O', 'L', 'O', 'N', 'E', 'L', 'C', 'O', 'N', 'T', 'D'],
#  [],
#  ['W'],
#  [],
#  ['L', 'W'],
#  [],
#  ['L'],
#  [],
#  ['I', 'B', 'A', 'C', 'K', 'G', 'R', 'O', 'U', 'N', 'D'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['F', 'A', 'D', 'E', 'T', 'O', 'B', 'L', 'A', 'C', 'K'],
#  [],
#  ['C', 'O', 'N', 'T', 'I', 'N', 'U', 'E', 'D'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['F', 'A', 'D', 'E', 'U', 'P'],
#  [],
#  ['I',
#   'N',
#   'T',
#   'D',
#   'O',
#   'R',
#   'C',
#   'H',
#   'E',
#   'S',
#   'T',
#   'E',
#   'R',
#   'H',
#   'O',
#   'T',
#   'E',
#   'L',
#   'L',
#   'O',
#   'N',
#   'D',
#   'O',
#   'N',
#   'D',
#   'A',
#   'Y'],
#  [],
#  ['A', 'M', 'A', 'N'],
#  [],
#  ['D', 'M', 'I', 'T'],
#  [],
#  ['H'],
#  [],
#  [],
#  [],
#  ['I',
#   'N',
#   'T',
#   'P',
#   'R',
#   'E',
#   'S',
#   'I',
#   'D',
#   'E',
#   'N',
#   'T',
#   'I',
#   'A',
#   'L',
#   'S',
#   'U',
#   'I',
#   'T',
#   'E',
#   'D',
#   'O',
#   'R',
#   'C',
#   'H',
#   'E',
#   'S',
#   'T',
#   'E',
#   'R',
#   'H',
#   'O',
#   'T',
#   'E',
#   'L',
#   'D',
#   'A',
#   'Y'],
#  [],
#  ['H'],
#  [],
#  ['M', 'I', 'O', 'F', 'F', 'I', 'C', 'E', 'R', 'O', 'S'],
#  [],
#  ['H', 'H'],
#  [],
#  [],
#  [],
#  ['A', 'S', 'A', 'U', 'D', 'I', 'P', 'R', 'I', 'N', 'C', 'E'],
#  [],
#  ['S', 'A', 'U', 'D', 'I', 'P', 'R', 'I', 'N', 'C', 'E'],
#  [],
#  ['Y', 'I'],
#  [],
#  ['M'],
#  [],
#  ['M', 'I', 'O', 'F', 'F', 'I', 'C', 'E', 'R'],
#  [],
#  ['I'],
#  [],
#  ['S', 'A', 'U', 'D', 'I', 'P', 'R', 'I', 'N', 'C', 'E'],
#  [],
#  ['M', 'I'],
#  [],
#  [],
#  [],
#  ['M', 'I', 'O', 'F', 'F', 'I', 'C', 'E', 'R'],
#  [],
#  ['I', 'E'],
#  [],
#  ['H'],
#  [],
#  ['C', 'U', 'T', 'T', 'O'],
#  [],
#  ['I',
#   'N',
#   'T',
#   'L',
#   'O',
#   'U',
#   'V',
#   'R',
#   'E',
#   'P',
#   'A',
#   'R',
#   'I',
#   'S',
#   'N',
#   'I',
#   'G',
#   'H',
#   'T'],
#  [],
#  ['A'],
#  [],
#  ['R', 'T', 'M', 'L'],
#  [],
#  ['M',
#   'A',
#   'N',
#   'F',
#   'R',
#   'E',
#   'D',
#   'P',
#   'I',
#   'C',
#   'A',
#   'R',
#   'D',
#   'F',
#   'N',
#   'M'],
#  [],
#  ['L', 'A', 'U', 'R', 'A', 'A', 'A'],
#  [],
#  ['T'],
#  [],
#  [],
#  [],
#  ['A'],
#  [],
#  ['M', 'A', 'N', 'F', 'R', 'E', 'D', 'P', 'I', 'C', 'A', 'R', 'D'],
#  [],
#  ['L', 'I'],
#  [],
#  [],
#  [],
#  ['C', 'O', 'N', 'T', 'I', 'N', 'U', 'E', 'D'],
#  [],
#  [],
#  [],
#  ['L', 'F'],
#  [],
#  ['L', 'A', 'U', 'R', 'A'],
#  [],
#  ['T'],
#  [],
#  ['M', 'T', 'W'],
#  [],
#  ['H', 'F'],
#  [],
#  [],
#  [],
#  ['I', 'B', 'A', 'C', 'K', 'G', 'R', 'O', 'U', 'N', 'D', 'M', 'L'],
#  [],
#  ['P'],
#  [],
#  ['H', 'M', 'L'],
#  [],
#  [],
#  [],
#  ['M', 'A', 'N', 'F', 'R', 'E', 'D', 'P', 'I', 'C', 'A', 'R', 'D'],
#  [],
#  ['A', 'T'],
#  [],
#  ['S', 'A'],
#  [],
#  ['L', 'A', 'U', 'R', 'A'],
#  [],
#  ['P'],
#  [],
#  ['P', 'T', 'C', 'A', 'M', 'E', 'R', 'A', 'M', 'O', 'V', 'E', 'S', 'I', 'N'],
#  [],
#  ['M', 'L'],
#  [],
#  [],
#  [],
#  ['F', 'A', 'D', 'E', 'T', 'O', 'B', 'L', 'A', 'C', 'K'],
#  [],
#  [],
#  [],
#  ['F', 'A', 'D', 'E', 'U', 'P'],
#  [],
#  ['F', 'U', 'Z', 'Z', 'Y', 'T', 'V', 'I', 'M', 'A', 'G', 'E', 'S'],
#  [],
#  ['L', 'T'],
#  [],
#  ['I'],
#  [],
#  ['T'],
#  [],
#  ['N', 'E', 'W', 'S', 'C', 'A', 'S', 'T', 'E', 'R', 'O', 'S'],
#  [],
#  ['T'],
#  [],
#  ['B', 'B', 'C'],
#  [],
#  ['M', 'T'],
#  [],
#  ['M'],
#  [],
#  [],
#  [],
#  ['N', 'E', 'W', 'S', 'C', 'A', 'S', 'T', 'E', 'R', 'C', 'O', 'N', 'T', 'D'],
#  [],
#  [],
#  [],
#  ['M', 'Q', 'C'],
#  [],
#  [],
#  [],
#  ['D'],
#  [],
#  [],
#  [],
#  ['T', 'C', 'A', 'M', 'E', 'R', 'A'],
#  [],
#  [],
#  [],
#  ['I',
#   'N',
#   'T',
#   'J',
#   'A',
#   'C',
#   'K',
#   'S',
#   'O',
#   'N',
#   'S',
#   'A',
#   'P',
#   'A',
#   'R',
#   'T',
#   'M',
#   'E',
#   'N',
#   'T',
#   'L',
#   'O',
#   'S',
#   'A',
#   'N',
#   'G',
#   'E',
#   'L',
#   'E',
#   'S',
#   'E',
#   'A',
#   'R',
#   'L',
#   'Y',
#   'M',
#   'O',
#   'R',
#   'N',
#   'I',
#   'N',
#   'G'],
#  [],
#  ['A', 'S', 'T', 'T', 'V'],
#  [],
#  ['N', 'E', 'W', 'S', 'C', 'A', 'S', 'T', 'E', 'R', 'O', 'S'],
#  [],
#  ['S'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A'],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N', 'C', 'U', 'R', 'T', 'I', 'S', 'H'],
#  [],
#  [],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N'],
#  [],
#  ['O', 'N'],
#  [],
#  ['O', 'H'],
#  [],
#  ['H'],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N', 'C', 'O', 'N', 'T', 'D'],
#  [],
#  ['H', 'W', 'I'],
#  [],
#  ['I'],
#  [],
#  ['J', 'T', 'V'],
#  [],
#  ['A'],
#  [],
#  [],
#  [],
#  ['F', 'A'],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N', 'C', 'O', 'N', 'T', 'D'],
#  [],
#  ['D'],
#  [],
#  [],
#  [],
#  ['K', 'I', 'F'],
#  [],
#  [],
#  [],
#  ['F', 'W'],
#  [],
#  ['J'],
#  [],
#  [],
#  [],
#  ['E',
#   'X',
#   'T',
#   'J',
#   'A',
#   'C',
#   'K',
#   'S',
#   'O',
#   'N',
#   'S',
#   'G',
#   'A',
#   'R',
#   'A',
#   'G',
#   'E',
#   'L',
#   'O',
#   'S',
#   'A',
#   'N',
#   'G',
#   'E',
#   'L',
#   'E',
#   'S',
#   'E',
#   'A',
#   'R',
#   'L',
#   'Y',
#   'M',
#   'O',
#   'R',
#   'N',
#   'I',
#   'N',
#   'G'],
#  [],
#  ['T', 'J'],
#  [],
#  ['S', 'U', 'V'],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N'],
#  [],
#  ['T', 'K'],
#  [],
#  ['I'],
#  [],
#  ['Y'],
#  [],
#  ['F'],
#  [],
#  ['H'],
#  [],
#  ['F'],
#  [],
#  [],
#  [],
#  ['E',
#   'X',
#   'T',
#   'J',
#   'A',
#   'C',
#   'K',
#   'S',
#   'O',
#   'N',
#   'S',
#   'S',
#   'T',
#   'R',
#   'E',
#   'E',
#   'T',
#   'L',
#   'O',
#   'S',
#   'A',
#   'N',
#   'G',
#   'E',
#   'L',
#   'E',
#   'S',
#   'E',
#   'A',
#   'R',
#   'L',
#   'Y',
#   'M',
#   'O',
#   'R',
#   'N',
#   'I',
#   'N',
#   'G'],
#  [],
#  ['J'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N'],
#  [],
#  ['I'],
#  [],
#  ['Y', 'K', 'I'],
#  [],
#  [],
#  [],
#  ['H', 'H'],
#  [],
#  [],
#  [],
#  ['N', 'E', 'I', 'G', 'H', 'B', 'O', 'R'],
#  [],
#  ['M'],
#  [],
#  ['W'],
#  [],
#  ['J'],
#  [],
#  ['I',
#   'N',
#   'T',
#   'S',
#   'T',
#   'R',
#   'E',
#   'E',
#   'T',
#   'S',
#   'L',
#   'O',
#   'S',
#   'A',
#   'N',
#   'G',
#   'E',
#   'L',
#   'E',
#   'S',
#   'E',
#   'A',
#   'R',
#   'L',
#   'Y',
#   'M',
#   'O',
#   'R',
#   'N',
#   'I',
#   'N',
#   'G'],
#  [],
#  ['J', 'L', 'A'],
#  [],
#  ['R', 'A', 'D', 'I', 'O', 'H', 'O', 'S', 'T', 'O', 'S'],
#  [],
#  ['T'],
#  [],
#  [],
#  [],
#  ['C'],
#  [],
#  ['W'],
#  [],
#  ['R',
#   'A',
#   'D',
#   'I',
#   'O',
#   'H',
#   'O',
#   'S',
#   'T',
#   'O',
#   'S',
#   'C',
#   'O',
#   'N',
#   'T',
#   'D'],
#  [],
#  ['W'],
#  [],
#  [],
#  [],
#  ['J', 'H'],
#  [],
#  ['R', 'T', 'E', 'N'],
#  [],
#  ['E',
#   'X',
#   'T',
#   'K',
#   'A',
#   'T',
#   'E',
#   'S',
#   'H',
#   'O',
#   'U',
#   'S',
#   'E',
#   'L',
#   'O',
#   'S',
#   'A',
#   'N',
#   'G',
#   'E',
#   'L',
#   'E',
#   'S',
#   'M',
#   'O',
#   'R',
#   'N',
#   'I',
#   'N',
#   'G'],
#  [],
#  ['J', 'W'],
#  [],
#  ['R', 'A', 'D', 'I', 'O', 'H', 'O', 'S', 'T', 'O', 'S'],
#  [],
#  ['I'],
#  [],
#  ['L'],
#  [],
#  ['R'],
#  [],
#  ['J', 'T', 'N', 'O', 'A', 'H', 'L', 'I', 'L', 'L', 'Y'],
#  [],
#  ['T'],
#  [],
#  [],
#  [],
#  ['N', 'O', 'A', 'H'],
#  [],
#  ['J'],
#  [],
#  ['C', 'O', 'N', 'T', 'I', 'N', 'U', 'E', 'D'],
#  [],
#  [],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N'],
#  [],
#  ['D', 'J', 'N', 'I'],
#  [],
#  [],
#  [],
#  ['L'],
#  [],
#  ['L', 'I', 'L', 'L', 'Y', 'O', 'S'],
#  [],
#  ['N', 'L', 'D', 'S', 'B'],
#  [],
#  ['S', 'B'],
#  [],
#  ['A'],
#  [],
#  ['T', 'K', 'A', 'T', 'E', 'C', 'U', 'R', 'T', 'I', 'S'],
#  [],
#  ['K', 'A', 'T', 'E'],
#  [],
#  ['S', 'W'],
#  [],
#  [],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N'],
#  [],
#  ['T', 'M', 'I'],
#  [],
#  [],
#  [],
#  ['K', 'A', 'T', 'E'],
#  [],
#  ['O'],
#  [],
#  ['K',
#   'G',
#   'O',
#   'R',
#   'D',
#   'O',
#   'N',
#   'S',
#   'I',
#   'L',
#   'B',
#   'E',
#   'R',
#   'M',
#   'A',
#   'N'],
#  [],
#  ['P', 'B'],
#  [],
#  ['G', 'O', 'R', 'D', 'O', 'N'],
#  [],
#  [],
#  [],
#  ['S', 'I'],
#  [],
#  ['L', 'F', 'I'],
#  [],
#  [],
#  [],
#  ['J', 'G'],
#  [],
#  ['G', 'O', 'R', 'D', 'O', 'N', 'C', 'O', 'N', 'T', 'D'],
#  [],
#  ['H', 'A'],
#  [],
#  [],
#  [],
#  ['J'],
#  [],
#  ['N'],
#  [],
#  ['J', 'G'],
#  [],
#  ['K', 'A', 'T', 'E'],
#  [],
#  ['N'],
#  [],
#  [],
#  [],
#  ['S', 'J'],
#  [],
#  ['K', 'A', 'T', 'E', 'C', 'O', 'N', 'T', 'D'],
#  [],
#  ['L'],
#  [],
#  [],
#  [],
#  ['J', 'A', 'C', 'K', 'S', 'O', 'N'],
#  [],
#  ['S'],
#  [],
#  ['C', 'O', 'N', 'T', 'I', 'N', 'U', 'E', 'D'],
#  [],
#  [],
#  [],
#  ['H', 'S'],
#  [],
#  [],
#  [],
#  ['K', 'A', 'T', 'E'],
#  [],
#  ['J'],
#  [],
#  ['D'],
#  [],
#  [],
#  [],
#  ['H'],
#  [],
#  ['C', 'U', 'T', 'T', 'O'],
#  [],
#  ['E',
#   'X',
#   'T',
#   'S',
#   'H',
#   'I',
#   'P',
#   'D',
#   'E',
#   'C',
#   'K',
#   'S',
#   'A',
#   'N',
#   'F',
#   'R',
#   'A',
#   'N',
#   'C',
#   'I',
#   'S',
#   'C',
#   'O',
#   'H',
#   'A',
#   'R',
#   'B',
#   'O',
#   'R',
#   'D',
#   'A',
#   'Y'],
#  [],
#  ['H',
#   'A',
#   'R',
#   'R',
#   'Y',
#   'H',
#   'E',
#   'L',
#   'M',
#   'S',
#   'L',
#   'E',
#   'Y',
#   'T',
#   'O',
#   'N',
#   'Y',
#   'D',
#   'E',
#   'L',
#   'G',
#   'A',
#   'D',
#   'O'],
#  [],
#  ['F', 'S', 'H'],
#  [],
#  ['A', 'A', 'T', 'I', 'H'],
#  [],
#  ['T', 'J', 'N', 'H', 'H', 'T'],
#  [],
#  ['D'],
#  [],
#  ['H', 'A', 'R', 'R', 'Y'],
#  [],
#  ['S', 'J'],
#  [],
#  ['T', 'O', 'N', 'Y'],
#  [],
#  ['S'],
#  [],
#  ['H', 'A', 'R', 'R', 'Y'],
#  [],
#  ['W', 'T'],
#  [],
#  ['W'],
#  [],
#  ['T', 'O', 'N', 'Y'],
#  [],
#  ['A'],
#  [],
#  ['T', 'O', 'N', 'Y'],
#  [],
#  ['T'],
#  [],
#  ['H', 'A', 'R', 'R', 'Y'],
#  [],
#  ['A'],
#  [],
#  ['T', 'O', 'N', 'Y'],
#  [],
#  ['Y', 'I', 'H'],
#  [],
#  ...]

# %%
df=(df.set_index(['../data/Scripts/2012.txt'])
       .apply(lambda x: x.str.split('\n').explode())
       .reset_index())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-6cf5630cd605> in <module>
# ----> 1 df=(df.set_index(['../data/Scripts/2012.TXT'])
#       2        .apply(lambda x: x.str.split('\n').explode())
#       3        .reset_index())
#
# NameError: name 'df' is not defined

# %%
with open('../data/Scripts/2012.txt', 'r') as f:
    script = f.read()

# %%
df = pd.DataFrame(script)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-f993410ce722> in <module>
# ----> 1 df = pd.DataFrame(script)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     588         else:
#     589             if index is None or columns is None:
# --> 590                 raise ValueError("DataFrame constructor not properly called!")
#     591
#     592             if not dtype:
#
# ValueError: DataFrame constructor not properly called!

# %%
read_name_file('../data/Scripts/2012.TXT')
# Out:
#                                                       0
# 0                                                  2012
# 1                                            written by
# 2                       roland emmerich & harald kloser
# 3                                          second draft
# 4                                   february 19th, 2008
# ...                                                 ...
# 4913  the `freedom of the seas' is perched on a moun...
# 4914  surrounded by calm waters. behind it, they see...
# 4915          beautiful rainbow. this is the new world.
# 4916               and again we hear mozart's adagio...
# 4917                                            the end
#
# [4918 rows x 1 columns]

# %%
def baseline_bechdel_test(script):
    """Implements a baseline bechdel test which return True if two women are speaking
        Args:
            script: a parsed script from the IMSDBParser class
        Returns:
            Whether the test is passed
    """
    prev_speaker = None
    test_passed = False
    for speaker, line in read_name_file(script):
        if speaker in female_names:
            if prev_speaker != speaker and prev_speaker is not None: #two women are talking!
                test_passed = True
                break
            else:
                prev_speaker = speaker
        else:
            prev_speaker = None
    return test_passed

# %%
baseline_bechdel_test('../data/Scripts/187.TXT')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-b6d28f9ad3b4> in <module>
# ----> 1 baseline_bechdel_test('../data/Scripts/187.TXT')
#
# <ipython-input-20-e37bd5e9ee88> in baseline_bechdel_test(script)
#       8     prev_speaker = None
#       9     test_passed = False
# ---> 10     for speaker, line in read_name_file(script):
#      11         if speaker in female_names:
#      12             if prev_speaker != speaker and prev_speaker is not None: #two women are talking!
#
# ValueError: too many values to unpack (expected 2)

# %%
def read_name_file(filename):
    """Read a file containing a list of names
        Args:
            filename: a file containing a name for each row
        Returns:
            An array of names from the input file
    """
    names = []
    with open(filename, "r") as f:
        for line in f:
            if not line.startswith("#") and line.strip() != "":  # remove comments and empty lines
                names.append(line.strip().lower())
    return names


def baseline_bechdel_test(script):
    """Implements a baseline bechdel test which return True if two women are speaking
        Args:
            script: a parsed script from the IMSDBParser class
        Returns:
            Whether the test is passed
    """
    prev_speaker = None
    test_passed = False
    for speaker, line in script:
        if speaker in female_names:
            if prev_speaker != speaker and prev_speaker is not None: #two women are talking!
                test_passed = True
                break
            else:
                prev_speaker = speaker
        else:
            prev_speaker = None
    return test_passed


def complete_bechdel_test(script):
    """Implements the complete bechdel test
        Args:
            script: a parsed script from the IMSDBParser class
        Returns:
            Whether the test is passed
    """
    prev_speaker = None
    test_passed = False
    for speaker, line in script:
        if speaker in female_names: #woman talking
            if prev_speaker != speaker and prev_speaker is not None: #two women are talking...
                talking_about_men=False #are they talking about men?
                for name in male_names:
                    if name in line:
                        talking_about_men=True
                if talking_about_men:  # They're talking about men
                    test_passed = False
                else:  # They're not talking about men!
                    test_passed= True
            else:  # prev speaker was a male/this speaker
                prev_speaker = speaker
        else:  # if a woman-to-woman male-free discussion was completed, return True
            if test_passed==True:
                break
            else:
                prev_speaker = None
    return test_passed

female_names = "../data/female.txt"
male_names = "../data/male.txt"
male_names = read_name_file(male_names)
female_names = read_name_file(female_names)
#parser = IMSDBParser(male_names+female_names, n_scripts=100)
#scripts = parser.get_all_scripts()
#successful_movies = []  # this will store movies which passed the baseline test
#complete_successful_movies = []  # this will store movies which passed the complete test
#unsuccessful_movies = []  # this will store movies which didn't pass the complete test
#for script in scripts:
    #if baseline_bechdel_test(script):
    #    successful_movies.append(script)
#    if complete_bechdel_test(script):
#        complete_successful_movies.append(script)
#    else:
#        unsuccessful_movies.append(script)
print ("Bechdel Test completed!")
#print ("Parsed", len(scripts), "files!")
#print "Found", int(len(successful_movies)), "movies passing the Baseline Bechdel Test"
#print ("Found", int(len(complete_successful_movies)), "movies passing the Complete Bechdel Test")
#print "(", format(float(len(successful_movies))/len(scripts)*100, ".0f"), "% of movies for the baseline)"
#print (", format(float(len(complete_successful_movies))/len(scripts)*100, ".0f"), "% of movies for the complete test)"
#print ("Average number of lines for each script (successful/unsuccessful):")
#print (int(np.average([len(m) for m in complete_successful_movies])), int(np.average([len(m) for m in unsuccessful_movies]))
#print ("Average number of different characters for each script (successful/unsuccessful):")
#print (int(np.average([len(set([m[0] for m in movie])) for movie in complete_successful_movies])),\
#    int(np.average([len(set([m[0] for m in movie])) for movie in unsuccessful_movies])))
#print ("Average number of male characters for each script (successful/unsuccessful):")
#print int(np.average([len(set([m[0] for m in movie if m[0] in male_names])) for movie in complete_successful_movies])),\
#    int(np.average([len(set([m[0] for m in movie if m[0] in male_names])) for movie in unsuccessful_movies]))
#print ("Average number of female characters for each script (successful/unsuccessful):")
#print int(np.average([len(set([m[0] for m in movie if m[0] in female_names])) for movie in complete_successful_movies])),\
#    int(np.average([len(set([m[0] for m in movie if m[0] in female_names])) for movie in unsuccessful_movies]))
# Out:
# Bechdel Test completed!
